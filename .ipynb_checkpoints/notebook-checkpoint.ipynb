# %%
import numpy as np
import pandas as pd
accel = pd.read_csv("12_10-to-bh.csv")
accel.columns=['time', 'gFx', 'gFy', 'gFz', 'totalg']
print(accel.head())
# Out:
#       time    gFx    gFy    gFz  totalg
# 0  54:12.5 -0.090 -0.532 -0.654   0.848
# 1  54:12.5 -0.090 -0.532 -0.654   0.848
# 2  54:12.5 -0.145 -0.602 -0.643   0.893
# 3  54:12.5 -0.160 -0.582 -0.682   0.911
# 4  54:12.5 -0.117 -0.519 -0.776   0.941

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=10)
plt.rcParams['figure.constrained_layout.use'] = True

# plt.scatter(accel['time'], accel['gFx'], color='green', marker='.')
# plt.scatter(accel['time'], accel['gFy'], color='red', marker='o')
# plt.scatter(accel['time'], accel['gFz'], color='blue', marker='o')
plt.scatter(accel['time'], accel['totalg'], color='purple', marker='o')
plt.xlabel("Time")
plt.ylabel("Accelleration")

plt.show()

# %%
gps = pd.read_csv("12_10.csv")
gps.columns=['segment', 'latitude', 'longitude', 'altitude', 
            'Time (UTC ISO)', 'time(UTC)', 'time(local)', 'UNIX Epoch Time']
print(gps.head())
# Out:
#    segment   latitude  longitude  altitude            Time (UTC ISO)  \
# 0        1  53.345347  -6.256384  4.885848  2022-10-12T15:54:12.089Z
# 1        1  53.345340  -6.256398  4.876404  2022-10-12T15:54:16.145Z
# 2        1  53.345337  -6.256458  4.818297  2022-10-12T15:54:17.089Z
# 3        1  53.345341  -6.256476  4.818151  2022-10-12T15:54:18.089Z
# 4        1  53.345344  -6.256484  4.808808  2022-10-12T15:54:19.089Z
#
#                  time(UTC)              time(local)  UNIX Epoch Time
# 0  2022-10-12 15:54:12.089  2022-10-12 16:54:12.089     1.665590e+09
# 1  2022-10-12 15:54:16.145  2022-10-12 16:54:16.145     1.665590e+09
# 2  2022-10-12 15:54:17.089  2022-10-12 16:54:17.089     1.665590e+09
# 3  2022-10-12 15:54:18.089  2022-10-12 16:54:18.089     1.665590e+09
# 4  2022-10-12 15:54:19.089  2022-10-12 16:54:19.089     1.665590e+09

# %%
plt.rc('font', size=10)
plt.rcParams['figure.constrained_layout.use'] = True

plt.scatter(gps['longitude'], gps['latitude'], color='blue', marker='.')
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
plt.rc('font', size=10)

fig = plt.figure(figsize = (7, 7))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(gps['longitude'], gps['latitude'], gps['time(local)'], color='blue', marker='.')
ax.set_xlabel('longitude', fontweight ='bold')
ax.set_ylabel('latitude', fontweight ='bold')
ax.set_zlabel('time', fontweight ='bold')
ax.view_init(20, 75)
ax.dist = 10
